# %%
import shutil
import os
import time
import logging


from selenium import webdriver

from selenium.webdriver.common.by import By
from selenium.webdriver.support.select import Select
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from webdriver_manager.chrome import ChromeDriverManager

# from msedge.selenium_tools import Edge,EdgeOptions 
# from selenium.common.exceptions import TimeoutException
# from selenium.webdriver.edge.service import Service

# from selenium.webdriver.chrome.service import Service
# from selenium.webdriver.chrome.options import Options


# link http://localhost:8090/MOBILEvhm/Login?ReturnUrl=%2fMOBILEvhm%2fDevicesGroups%2fVHM.
#  Credentials for the application are inita/init (username/password). 
#  MOBILEefficiency can be accessed at http://10.194.172.21/init/Common/Login
#  (or at http://10.194.172.21/init/Efficiency/Dashboard/Main

# Enable headless mode
# edge_path = r'/edgedriver_win64/msedgedriver.exe'
# edge_options = EdgeOptions() 
# edge_options.add_argument("--headless=new")
# edge_options.use_chromium = True  
# edge_options.add_argument("start-maximized")  
# edge_options.add_argument("inprivate") 
# service = Service(executable_path=edge_path)

driver = webdriver.Chrome()

# chrome_options = Options()
# chrome_options.add_argument("--headless")
# driver = webdriver.Chrome()

url = r"http://cavl-pvme201:8090/MOBILEvhm/Login?ReturnUrl=%2fMOBILEvhm%2fDevicesGroups%2fVHM" 

# initialize the Chrome driver
driver.get(url)

# Mobile-Eco-2 Credentials
username = "inita"
password = "init"

driver.find_element("id", "UserShortName").send_keys(username)
driver.find_element("id", "Password").send_keys(password)




driver.find_element(By.XPATH, "//div[input/@name='loginRequest']/button[1]").click()

# print(get_url)


# Select tab along
URLS = {
        "fleetHistory":r"http://cavl-pvme201:8090/MOBILEvhm/DevicesGroups/FleetHistory",
        "vehHistory":r"http://cavl-pvme201:8090/MOBILEvhm/DevicesGroups/History",
        }

driver.get(URLS["vehHistory"])
# Select dropdownlist


# # Navigate to Veh ID input
# "8316"
veh_id = 8316
table1 = driver.find_element(By.XPATH,"//input[@id='comboBoxVehicleSearch_I']").send_keys(veh_id)




# Navigate to APPLY buttons
# <btn class="btn btn-primary" onclick="historyFilter_Submit()">Apply</btn>
table2 = driver.find_element(By.XPATH,"//btn[@onclick='historyFilter_Submit()']").click()



# Navigate to EXPORT button



wait = WebDriverWait(driver, 30)
wait.until(EC.presence_of_all_elements_located((By.XPATH,"//button[@type='button' and @aria-haspopup='true']")))


# selector
export_button = driver.find_element(By.XPATH,"//button[contains(text(),'Export')]").click()
export_csv = driver.find_element(By.XPATH,'//*[@id="historyParentCallback"]/div/div/div[4]/div/div/button[3]').click()

time.sleep(60)

# Move file

# Providing the folder path
origin = r'C:\Users\MelissaLu\Downloads'
target = r'C:\Users\MelissaLu\OneDrive - Metrolinx\Desktop\Projects\data dump'

downloaded_fn = "historyMasterGrid.csv"

my_file = os.path.join(origin,downloaded_fn)

target_loc = os.path.join(target,downloaded_fn)


# Fetching all the files to directory

shutil.move(my_file, target_loc)

os.chdir(target)

os.rename("historyMasterGrid.csv" , f"historyMasterGrid_{veh_id}.csv")
# Out:
# ---------------------------------------------------------------------------
# SeleniumManagerException                  Traceback (most recent call last)
# c:\Users\MelissaLu\Anaconda3\lib\site-packages\selenium\webdriver\common\service.py in start(self)
#      94                 "The executable %s needs to be available in the path. %s\n%s" %
# ---> 95                 (os.path.basename(self.path), self.start_error_message, str(e)))
#      96         count = 0
#
# c:\Users\MelissaLu\Anaconda3\lib\site-packages\selenium\webdriver\common\selenium_manager.py in driver_location(self, browser)
#
# c:\Users\MelissaLu\Anaconda3\lib\site-packages\selenium\webdriver\common\selenium_manager.py in get_binary()
#
# SeleniumManagerException: Message: c:\Users\MelissaLu\Anaconda3\lib\site-packages\selenium\webdriver\common\windows\selenium-manager.exe is missing.  Please open an issue on https://github.com/SeleniumHQ/selenium/issues
#
#
# During handling of the above exception, another exception occurred:
#
# WebDriverException                        Traceback (most recent call last)
# ~\AppData\Local\Temp\1\ipykernel_10016\2848786542.py in <module>
#      37 # service = Service(executable_path=edge_path)
#      38
# ---> 39 driver = webdriver.Chrome()
#      40
#      41 # chrome_options = Options()
#
# c:\Users\MelissaLu\Anaconda3\lib\site-packages\selenium\webdriver\chrome\webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, service, keep_alive)
#      78                 command_executor=ChromeRemoteConnection(
#      79                     remote_server_addr=self.service.service_url,
# ---> 80                     keep_alive=keep_alive),
#      81                 desired_capabilities=desired_capabilities)
#      82         except Exception:
#
# c:\Users\MelissaLu\Anaconda3\lib\site-packages\selenium\webdriver\chromium\webdriver.py in __init__(self, browser_name, vendor_prefix, port, options, service_args, desired_capabilities, service_log_path, service, keep_alive)
#
# c:\Users\MelissaLu\Anaconda3\lib\site-packages\selenium\webdriver\common\service.py in start(self)
#      96         count = 0
#      97         while True:
# ---> 98             self.assert_process_still_running()
#      99             if self.is_connectable():
#     100                 break
#
# c:\Users\MelissaLu\Anaconda3\lib\site-packages\selenium\webdriver\common\service.py in start(self)
#      86                 raise WebDriverException(
#      87                     "'%s' executable may have wrong permissions. %s" % (
# ---> 88                         os.path.basename(self.path), self.start_error_message)
#      89                 )
#      90             else:
#
# c:\Users\MelissaLu\Anaconda3\lib\site-packages\selenium\webdriver\common\service.py in _start_process(self, path)
#
# WebDriverException: Message: 'chromedriver' executable needs to be in PATH. Please see https://chromedriver.chromium.org/home
